# %%
#Dependencies: 
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime as dt
import time 
import calendar
from numpy import array

# %%
#Import Data: 
df=pd.read_csv('./Data/Accidental_Drug_Related_Deaths_2012-2018_Clean.csv')
df.head()
# Out:
#         ID            Date   Age     Sex          Race ResidenceCity  \
# 0  14-0273  6/28/2014 0:00   NaN     NaN           NaN           NaN
# 1  13-0102  3/21/2013 0:00  48.0    Male         Black       NORWALK
# 2  16-0165  3/13/2016 0:00  30.0  Female         White    SANDY HOOK
# 3  16-0208  3/31/2016 0:00  23.0    Male         White           RYE
# 4  13-0052  2/13/2013 0:00  22.0    Male  Asian, Other      FLUSHING
#
#   ResidenceCounty ResidenceState  DeathCity DeathCounty  ...  \
# 0             NaN            NaN        NaN         NaN  ...
# 1             NaN            NaN    NORWALK   FAIRFIELD  ...
# 2       FAIRFIELD             CT    DANBURY         NaN  ...
# 3     WESTCHESTER             NY  GREENWICH         NaN  ...
# 4          QUEENS            NaN  GREENWICH   FAIRFIELD  ...
#
#                                         COD Heroin Cocaine Fentanyl  \
# 0      Acute fent, hydrocod, benzodiazepine    NaN     NaN        Y
# ...

# %%
#Fix the date format:
df["Date"] = pd.to_datetime(df["Date"])
df.head()
# Out:
#         ID       Date   Age     Sex          Race ResidenceCity  \
# 0  14-0273 2014-06-28   NaN     NaN           NaN           NaN
# 1  13-0102 2013-03-21  48.0    Male         Black       NORWALK
# 2  16-0165 2016-03-13  30.0  Female         White    SANDY HOOK
# 3  16-0208 2016-03-31  23.0    Male         White           RYE
# 4  13-0052 2013-02-13  22.0    Male  Asian, Other      FLUSHING
#
#   ResidenceCounty ResidenceState  DeathCity DeathCounty  ...  \
# 0             NaN            NaN        NaN         NaN  ...
# 1             NaN            NaN    NORWALK   FAIRFIELD  ...
# 2       FAIRFIELD             CT    DANBURY         NaN  ...
# 3     WESTCHESTER             NY  GREENWICH         NaN  ...
# 4          QUEENS            NaN  GREENWICH   FAIRFIELD  ...
#
#                                         COD Heroin Cocaine Fentanyl  \
# 0      Acute fent, hydrocod, benzodiazepine    NaN     NaN        Y
# 1                      Cocaine Intoxication    NaN       Y      NaN
# ...

# %%
#Make the total death column:
df['ID']=df["ID"].str.replace('-', '')
df['ID']=df['ID'].astype('int64', errors='ignore')
df.ID.head()
# Out:
# 0    140273
# 1    130102
# 2    160165
# 3    160208
# 4    130052
# Name: ID, dtype: int64

# %%
df['Date'] = df.Date.map(dt.toordinal)

# %%
ser=pd.Series(index='Date', data='ID')
ser_df=ser.to_frame()

ser_df.reset_index(inplace=True)
ser_df.columns=['Years', 'Deaths']
ser_df.plot(kind='scatter', x='Date', y='ID')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0941e6bc4b4e> in <module>
# ----> 1 ser=df(index='Date', data='ID')
#       2 ser_df=ser.to_frame()
#       3
#       4 ser_df.reset_index(inplace=True)
#       5 ser_df.columns=['Years', 'Deaths']
#
# TypeError: 'DataFrame' object is not callable
