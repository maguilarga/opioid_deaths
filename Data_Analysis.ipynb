# %%
import pandas as pd

# %%
df = pd.read_csv("Data/Accidental_Drug_Related_Deaths_2012-2018.csv")
df.head()
# Out:
#         ID                    Date      DateType   Age     Sex          Race  \
# 0  14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %%
df.count()
# Out:
# ID                     5105
# Date                   5103
# DateType               5103
# Age                    5102
# Sex                    5099
# Race                   5092
# ResidenceCity          4932
# ResidenceCounty        4308
# ResidenceState         3556
# DeathCity              5100
# DeathCounty            4005
# Location               5081
# LocationifOther         590
# DescriptionofInjury    4325
# InjuryPlace            5039
# InjuryCity             3349
# InjuryCounty           2364
# InjuryState            1424
# COD                    5105
# OtherSignifican         169
# Heroin                 2529
# Cocaine                1521
# Fentanyl               2232
# FentanylAnalogue        389
# Oxycodone               607
# Oxymorphone             108
# Ethanol                1247
# Hydrocodone             118
# Benzodiazepine         1343
# Methadone               474
# Amphet                  159
# Tramad                  130
# Morphine_NotHeroin       42
# ...

# %%
df.dtypes
# Out:
# ID                      object
# Date                    object
# DateType                object
# Age                    float64
# Sex                     object
# Race                    object
# ResidenceCity           object
# ResidenceCounty         object
# ResidenceState          object
# DeathCity               object
# DeathCounty             object
# Location                object
# LocationifOther         object
# DescriptionofInjury     object
# InjuryPlace             object
# InjuryCity              object
# InjuryCounty            object
# InjuryState             object
# COD                     object
# OtherSignifican         object
# Heroin                  object
# Cocaine                 object
# Fentanyl                object
# FentanylAnalogue        object
# Oxycodone               object
# Oxymorphone             object
# Ethanol                 object
# Hydrocodone             object
# Benzodiazepine          object
# Methadone               object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'DateType', 'Age', 'Sex', 'Race', 'ResidenceCity',
#        'ResidenceCounty', 'ResidenceState', 'DeathCity', 'DeathCounty',
#        'Location', 'LocationifOther', 'DescriptionofInjury', 'InjuryPlace',
#        'InjuryCity', 'InjuryCounty', 'InjuryState', 'COD', 'OtherSignifican',
#        'Heroin', 'Cocaine', 'Fentanyl', 'FentanylAnalogue', 'Oxycodone',
#        'Oxymorphone', 'Ethanol', 'Hydrocodone', 'Benzodiazepine', 'Methadone',
#        'Amphet', 'Tramad', 'Morphine_NotHeroin', 'Hydromorphone', 'Other',
#        'OpiateNOS', 'AnyOpioid', 'MannerofDeath', 'DeathCityGeo',
#        'ResidenceCityGeo', 'InjuryCityGeo'],
#       dtype='object')

# %%
df[['DeathCity','ResidenceCity','InjuryCity','DeathCityGeo','ResidenceCityGeo', 'InjuryCityGeo']].head()
# Out:
#    DeathCity ResidenceCity InjuryCity                            DeathCityGeo  \
# 0        NaN           NaN        NaN             CT\n(41.575155, -72.738288)
# 1    NORWALK       NORWALK        NaN     Norwalk, CT\n(41.11805, -73.412906)
# 2    DANBURY    SANDY HOOK    UNKNOWN    Danbury, CT\n(41.393666, -73.451539)
# 3  GREENWICH           RYE        RYE  Greenwich, CT\n(41.026526, -73.628549)
# 4  GREENWICH      FLUSHING        NaN  Greenwich, CT\n(41.026526, -73.628549)
#
#                           ResidenceCityGeo                InjuryCityGeo
# 0              CT\n(41.575155, -72.738288)  CT\n(41.575155, -72.738288)
# 1      NORWALK, CT\n(41.11805, -73.412906)  CT\n(41.575155, -72.738288)
# 2  SANDY HOOK, CT\n(41.419998, -73.282501)                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN  CT\n(41.575155, -72.738288)

# %%
# df['DeathCityGeo'].value_counts()

# %%
import re
# s = df.loc[:,'DeathCityGeo']

# # re.search('\(([^)]+)', s).group(1)
# re.findall('\(([^)]+)', s)

# df['DeathCityGeo']= df['DeathCityGeo'].str.replace("\s+\(.*$", "")

# df['DeathCityGeo2'] = df.DeathCityGeo.str.split('\(|\)', expand=True).iloc[:,[0]]

df['DeathCityGeo'] =df.loc[:,'DeathCityGeo'].str.extract('.*\((.*)\).*')
df['ResidenceCityGeo'] =df.loc[:,'ResidenceCityGeo'].str.extract('.*\((.*)\).*')
df['InjuryCityGeo'] =df.loc[:,'InjuryCityGeo'].str.extract('.*\((.*)\).*')
df.head()
# Out:
#         ID                    Date      DateType   Age     Sex          Race  \
# 0  14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %%
df['ResidenceCityGeo'].dtype
# Out:
# dtype('O')

# %%
df['DeathCityLat'] = df.DeathCityGeo.str.split(', ').apply(lambda x: x[0])
df['DeathCityLong'] = df.DeathCityGeo.str.split(', ').apply(lambda x: x[1])

# df['longitude'] = lon
df.head()
# Out:
#         ID                    Date      DateType   Age     Sex          Race  \
# 0  14-0273  06/28/2014 12:00:00 AM  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013 12:00:00 AM   DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016 12:00:00 AM   DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016 12:00:00 AM   DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013 12:00:00 AM   DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Hydromorphone  \
# 0           NaN             NaN            NaN        NaN  ...           NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...           NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...           NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...           NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...           NaN
#
# ...

# %%
df['MannerofDeath'].value_counts()
# Out:
# Accident    5066
# Pending       14
# accident      13
# ACCIDENT       1
# Natural        1
# Name: MannerofDeath, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-63beda18e948> in <module>
# ----> 1 df['ResidenceCityLat'] = df.ResidenceCityGeo.str.split(', ').apply(lambda x: x[0])
#       2 df['ResidenceCityLong'] = df.ResidenceCityGeo.str.split(', ').apply(lambda x: x[1])
#       3
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-58-63beda18e948> in <lambda>(x)
# ----> 1 df['ResidenceCityLat'] = df.ResidenceCityGeo.str.split(', ').apply(lambda x: x[0])
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-910d65f4a518> in <module>
# ----> 1 df['InjuryCityLat'] = df.InjuryCityGeo.str.split(', ').apply(lambda x: x[0])
#       2 df['InjuryCityLong'] = df.InjuryCityGeo.str.split(', ').apply(lambda x: x[1])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-59-910d65f4a518> in <lambda>(x)
# ----> 1 df['InjuryCityLat'] = df.InjuryCityGeo.str.split(', ').apply(lambda x: x[0])
# ...

# %%
df.to_csv("Accidental_Drug_Related_Deaths_2012-2018_2.csv",
                  encoding="utf-8", index=False, header=True)
